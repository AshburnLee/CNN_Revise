# %%
import tensorflow as tf
import os
import pickle
import numpy as np
import CifarData
CIFAR_DIR = "./../cifar-10-batches-py/"
print(os.listdir(CIFAR_DIR))
# Out:
# ['batches.meta', 'data_batch_1', 'data_batch_2', 'data_batch_3', 'data_batch_4', 'data_batch_5', 'readme.html', 'test_batch']

# %%
# tensorboard
# 1. 指定面板图上显示的变量
# 2. 训练过程中将这些变量计算出来，输出到文件中
# 3. 文件解析 ./tensorboard --logdir=dir.

# %%
train_filenames = [os.path.join(CIFAR_DIR, 'data_batch_%d' % i) for i in range(1, 6)]
test_filenames = [os.path.join(CIFAR_DIR, 'test_batch')]

train_data = CifarData.CifarData(train_filenames, True)
test_data = CifarData.CifarData(test_filenames, False)
# Out:
# (50000, 3072)
# (50000,)
# (10000, 3072)
# (10000,)

# %%
x = tf.placeholder(tf.float32, [None, 3072])
y = tf.placeholder(tf.int64, [None])
# [None], eg: [0,5,6,3]
x_image = tf.reshape(x, [-1, 3, 32, 32])
# 32*32
x_image = tf.transpose(x_image, perm=[0, 2, 3, 1])

# conv1: 神经元图， feature_map, 输出图像
conv1_1 = tf.layers.conv2d(x_image,
                           32, # output channel number
                           (3,3), # kernel size
                           padding = 'same',
                           activation = tf.nn.relu,
                           name = 'conv1_1')
conv1_2 = tf.layers.conv2d(conv1_1,
                           32, # output channel number
                           (3,3), # kernel size
                           padding = 'same',
                           activation = tf.nn.relu,
                           name = 'conv1_2')

# 16 * 16
pooling1 = tf.layers.max_pooling2d(conv1_2,
                                   (2, 2), # kernel size
                                   (2, 2), # stride
                                   name = 'pool1')


conv2_1 = tf.layers.conv2d(pooling1,
                           32, # output channel number
                           (3,3), # kernel size
                           padding = 'same',
                           activation = tf.nn.relu,
                           name = 'conv2_1')
conv2_2 = tf.layers.conv2d(conv2_1,
                           32, # output channel number
                           (3,3), # kernel size
                           padding = 'same',
                           activation = tf.nn.relu,
                           name = 'conv2_2')
# 8 * 8
pooling2 = tf.layers.max_pooling2d(conv2_2,
                                   (2, 2), # kernel size
                                   (2, 2), # stride
                                   name = 'pool2')

conv3_1 = tf.layers.conv2d(pooling2,
                           32, # output channel number
                           (3,3), # kernel size
                           padding = 'same',
                           activation = tf.nn.relu,
                           name = 'conv3_1')
conv3_2 = tf.layers.conv2d(conv3_1,
                           32, # output channel number
                           (3,3), # kernel size
                           padding = 'same',
                           activation = tf.nn.relu,
                           name = 'conv3_2')
# 4 * 4 * 32
pooling3 = tf.layers.max_pooling2d(conv3_2,
                                   (2, 2), # kernel size
                                   (2, 2), # stride
                                   name = 'pool3')
# [None, 4 * 4 * 32]
flatten = tf.layers.flatten(pooling3)
y_ = tf.layers.dense(flatten, 10)

loss = tf.losses.sparse_softmax_cross_entropy(labels=y, logits=y_)
# y_ -> sofmax
# y -> one_hot
# loss = ylogy_

# indices
predict = tf.argmax(y_, 1)
# [1,0,1,1,1,0,0,0]
correct_prediction = tf.equal(predict, y)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float64))

with tf.name_scope('train_op'):
    train_op = tf.train.AdamOptimizer(1e-3).minimize(loss)

# %%
def variable_summary(var, name):
    """Constructs summary for statistics of a variable"""
    with tf.name_scope(name):
        mean = tf.reduce_meanvar)
        with tf.name_scope('stddev'):
            stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
        tf.summary.scalar('mean', mean)
        tf.summary.scalar('stddev', stddev)
        tf.summary.scalar('min', tf.reduce_min(var))
        tf.summary.scalar('max', tf.reduce_max(var))
        tf.summary.histogram('histogram', var)

# apply it to all nodes, 
with tf.name_scope('summary'):
    variable_summary(conv1_1, 'conv1_1')
    variable_summary(conv1_2, 'conv1_2')
    variable_summary(conv2_1, 'conv2_1')
    variable_summary(conv2_2, 'conv2_2')
    variable_summary(conv3_1, 'conv3_1')
    variable_summary(conv3_2, 'conv3_2')

"""
Create summary for tensorboard
"""
# we care about loss & accuracy the most:
#1) loss
loss_summary = tf.summary.scalar('loss', loss)
# 'loss': <10, 1.1>, <20, 1.08>
#2) accuracy
accuracy_summary = tf.summary.scalar('accuracy', accuracy)

#3) source_image
source_image = (x_image + 1) * 127.5  # reverse normalization
inputs_summary = tf.summary.image('inputs_image', source_image)

# two way to merge 'summary's
merged_summary = tf.summary.merge_all()
merged_summary_test = tf.summary.merge([loss_summary, accuracy_summary])


# create a paths(folders)
LOG_DIR = '.'
run_label = './run_vgg_tensorboard'
run_dir = os.path.join(LOG_DIR, run_label)
if not os.path.exists(run_dir):
    os.mkdir(run_dir)

# training folder 
train_log_dir = os.path.join(run_dir, 'train')
# prediction folder
test_log_dir = os.path.join(run_dir, 'test')
if not os.path.exists(train_log_dir):
    os.mkdir(train_log_dir)
if not os.path.exists(test_log_dir):
    os.mkdir(test_log_dir)

# %%
init = tf.global_variables_initializer()
batch_size = 20
train_steps = 10000
test_steps = 100

# output summary every 100 steps
output_summary_every_steps = 100


# train 10000: 70.45%
with tf.Session() as sess:
    sess.run(init)
    
    #
    train_writer = tf.summary.FileWriter(train_log_dir, sess.graph)
    test_writer = tf.summary.FileWriter(test_log_dir)
    
    fixed_test_batch_data, fixed_test_batch_labels = test_data.next_batch(batch_size)

    for i in range(train_steps):
        batch_data, batch_labels = train_data.next_batch(batch_size)
        
        #
        eval_ops = [loss, accuracy, train_op]  # eval_op contains items to 'run'
        should_output_summary = ((i+1) % output_summary_every_steps == 0)
        if should_output_summary:
            eval_ops.append(merged_summary)
        eval_ops_results = sess.run(
                                    eval_ops,
                                    feed_dict={
                                        x: batch_data,
                                        y: batch_labels}
                                    )
        loss_val, acc_val = eval_ops_results[0:2]
        #
        if should_output_summary:
            train_summary_str = eval_ops_results[-1]
            train_writer.add_summary(train_summary_str, i+1)
            
            # in test, we choose the same batch to test!!
            test_summary_str = sess.run([merged_summary_test],
                                        feed_dict={
                                            x: fixed_test_batch_data,
                                            y: fixed_test_batch_labels,
                                        })[0]
            test_writer.add_summary(test_summary_str, i+1)
    
        if (i+1) % 100 == 0:
            print('[Train] Step: %d, loss: %4.5f, acc: %4.5f' 
                  % (i+1, loss_val, acc_val))
        if (i+1) % 1000 == 0:
            test_data = CifarData.CifarData(test_filenames, False)
            all_test_acc_val = []
            for j in range(test_steps):
                test_batch_data, test_batch_labels = test_data.next_batch(batch_size)
                test_acc_val = sess.run(
                                        [accuracy],
                                        feed_dict = {
                                            x: test_batch_data, 
                                            y: test_batch_labels
                                        })
                all_test_acc_val.append(test_acc_val)
            test_acc = np.mean(all_test_acc_val)
            print('[Test ] Step: %d, acc: %4.5f' % (i+1, test_acc))
# Out:
# [Train] Step: 100, loss: 2.07766, acc: 0.30000
# [Train] Step: 200, loss: 2.00673, acc: 0.25000
# [Train] Step: 300, loss: 1.70037, acc: 0.40000
# [Train] Step: 400, loss: 1.84755, acc: 0.30000
# [Train] Step: 500, loss: 1.77263, acc: 0.25000
# [Train] Step: 600, loss: 1.36166, acc: 0.65000
# [Train] Step: 700, loss: 1.44902, acc: 0.65000
# [Train] Step: 800, loss: 1.40021, acc: 0.45000
# [Train] Step: 900, loss: 2.10793, acc: 0.30000
# [Train] Step: 1000, loss: 1.13465, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step: 1000, acc: 0.49950
# [Train] Step: 1100, loss: 1.31510, acc: 0.55000
# [Train] Step: 1200, loss: 1.22702, acc: 0.70000
# [Train] Step: 1300, loss: 1.04106, acc: 0.65000
# [Train] Step: 1400, loss: 1.45412, acc: 0.40000
# [Train] Step: 1500, loss: 1.26331, acc: 0.65000
# [Train] Step: 1600, loss: 1.22606, acc: 0.50000
# [Train] Step: 1700, loss: 0.99629, acc: 0.65000
# [Train] Step: 1800, loss: 1.08484, acc: 0.50000
# [Train] Step: 1900, loss: 0.68985, acc: 0.70000
# [Train] Step: 2000, loss: 1.00557, acc: 0.60000
# (10000, 3072)
# (10000,)
# [Test ] Step: 2000, acc: 0.58000
# [Train] Step: 2100, loss: 0.80912, acc: 0.70000
# [Train] Step: 2200, loss: 1.16352, acc: 0.65000
# [Train] Step: 2300, loss: 1.27875, acc: 0.65000
# [Train] Step: 2400, loss: 1.11520, acc: 0.65000
# [Train] Step: 2500, loss: 1.23874, acc: 0.55000
# [Train] Step: 2600, loss: 0.99011, acc: 0.65000
# [Train] Step: 2700, loss: 1.07989, acc: 0.60000
# [Train] Step: 2800, loss: 1.72401, acc: 0.50000
# [Train] Step: 2900, loss: 1.25290, acc: 0.55000
# [Train] Step: 3000, loss: 1.19353, acc: 0.65000
# (10000, 3072)
# (10000,)
# [Test ] Step: 3000, acc: 0.59900
# [Train] Step: 3100, loss: 0.89496, acc: 0.80000
# [Train] Step: 3200, loss: 0.94479, acc: 0.75000
# [Train] Step: 3300, loss: 0.70320, acc: 0.80000
# [Train] Step: 3400, loss: 0.78445, acc: 0.70000
# [Train] Step: 3500, loss: 0.95344, acc: 0.65000
# [Train] Step: 3600, loss: 0.76468, acc: 0.80000
# [Train] Step: 3700, loss: 1.23623, acc: 0.45000
# [Train] Step: 3800, loss: 1.30797, acc: 0.50000
# [Train] Step: 3900, loss: 0.90013, acc: 0.65000
# [Train] Step: 4000, loss: 0.85595, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step: 4000, acc: 0.65300
# [Train] Step: 4100, loss: 0.85738, acc: 0.55000
# [Train] Step: 4200, loss: 1.15221, acc: 0.65000
# [Train] Step: 4300, loss: 0.85112, acc: 0.75000
# [Train] Step: 4400, loss: 0.99928, acc: 0.70000
# [Train] Step: 4500, loss: 1.16510, acc: 0.60000
# [Train] Step: 4600, loss: 0.96719, acc: 0.65000
# [Train] Step: 4700, loss: 0.94436, acc: 0.65000
# [Train] Step: 4800, loss: 1.37715, acc: 0.55000
# [Train] Step: 4900, loss: 0.86019, acc: 0.80000
# [Train] Step: 5000, loss: 1.16739, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step: 5000, acc: 0.68000
# [Train] Step: 5100, loss: 1.34756, acc: 0.55000
# [Train] Step: 5200, loss: 1.18582, acc: 0.65000
# [Train] Step: 5300, loss: 0.84808, acc: 0.75000
# [Train] Step: 5400, loss: 0.89590, acc: 0.65000
# [Train] Step: 5500, loss: 0.65718, acc: 0.65000
# [Train] Step: 5600, loss: 0.65619, acc: 0.80000
# [Train] Step: 5700, loss: 0.77489, acc: 0.80000
# [Train] Step: 5800, loss: 0.63226, acc: 0.70000
# [Train] Step: 5900, loss: 0.96807, acc: 0.65000
# [Train] Step: 6000, loss: 0.99861, acc: 0.70000
# (10000, 3072)
# (10000,)
# [Test ] Step: 6000, acc: 0.69450
# [Train] Step: 6100, loss: 0.82156, acc: 0.70000
# [Train] Step: 6200, loss: 0.89494, acc: 0.70000
# [Train] Step: 6300, loss: 1.20013, acc: 0.60000
# [Train] Step: 6400, loss: 1.02644, acc: 0.60000
# [Train] Step: 6500, loss: 1.31711, acc: 0.55000
# [Train] Step: 6600, loss: 0.79269, acc: 0.75000
# [Train] Step: 6700, loss: 0.49192, acc: 0.90000
# [Train] Step: 6800, loss: 0.27544, acc: 0.90000
# [Train] Step: 6900, loss: 0.57070, acc: 0.75000
# [Train] Step: 7000, loss: 0.83313, acc: 0.85000
# (10000, 3072)
# (10000,)
# [Test ] Step: 7000, acc: 0.70500
# [Train] Step: 7100, loss: 0.54332, acc: 0.65000
# [Train] Step: 7200, loss: 0.59341, acc: 0.85000
# [Train] Step: 7300, loss: 0.70480, acc: 0.70000
# [Train] Step: 7400, loss: 0.57058, acc: 0.85000
# [Train] Step: 7500, loss: 0.93317, acc: 0.80000
# [Train] Step: 7600, loss: 0.88101, acc: 0.75000
# [Train] Step: 7700, loss: 0.42144, acc: 0.85000
# [Train] Step: 7800, loss: 0.57888, acc: 0.80000
# [Train] Step: 7900, loss: 0.92035, acc: 0.60000
# [Train] Step: 8000, loss: 0.67999, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step: 8000, acc: 0.70800
# [Train] Step: 8100, loss: 1.07174, acc: 0.70000
# [Train] Step: 8200, loss: 1.04477, acc: 0.60000
# [Train] Step: 8300, loss: 0.75398, acc: 0.80000
# [Train] Step: 8400, loss: 0.65263, acc: 0.70000
# [Train] Step: 8500, loss: 0.68599, acc: 0.75000
# [Train] Step: 8600, loss: 1.16666, acc: 0.55000
# [Train] Step: 8700, loss: 1.00337, acc: 0.65000
# [Train] Step: 8800, loss: 1.07769, acc: 0.55000
# [Train] Step: 8900, loss: 0.49181, acc: 0.75000
# [Train] Step: 9000, loss: 0.67697, acc: 0.80000
# (10000, 3072)
# (10000,)
# [Test ] Step: 9000, acc: 0.71650
# [Train] Step: 9100, loss: 1.10604, acc: 0.65000
# [Train] Step: 9200, loss: 0.64645, acc: 0.80000
# [Train] Step: 9300, loss: 0.32777, acc: 0.85000
# [Train] Step: 9400, loss: 0.84918, acc: 0.70000
# [Train] Step: 9500, loss: 0.64209, acc: 0.80000
# [Train] Step: 9600, loss: 0.94906, acc: 0.75000
# [Train] Step: 9700, loss: 0.51369, acc: 0.80000
# [Train] Step: 9800, loss: 0.53237, acc: 0.75000
# [Train] Step: 9900, loss: 0.81762, acc: 0.70000
# [Train] Step: 10000, loss: 0.77872, acc: 0.75000
# (10000, 3072)
# (10000,)
# [Test ] Step: 10000, acc: 0.72950

# %%
# go to log directory
# use this command to open tensorboad:
# $tensorboard --logdir=train:'train',test:'test'
# test: the folder under the log, containing events for test; 'test' is its name
# train: the folder under the log, containing events for train; 'train' is its name
